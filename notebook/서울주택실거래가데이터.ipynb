# %%
csvFile ='C:/Users/student/Downloads/서울시 부동산 실거래가 정보.csv'

# %%
import pandas as pd

df = pd.read_csv(csvFile, encoding='cp949')
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_5456\710038303.py:3: DtypeWarning: Columns (7,15,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csvFile, encoding='cp949')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2646181 entries, 0 to 2646180
# Data columns (total 21 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   접수연도              int64
#  1   자치구코드             int64
#  2   자치구명              object
#  3   법정동코드             int64
#  4   법정동명              object
#  5   지번구분              float64
#  6   지번구분명             object
#  7   본번                object
#  8   부번                float64
#  9   건물명               object
#  10  계약일               int64
#  11  물건금액(만원)          int64
#  12  건물면적(㎡)           float64
#  13  토지면적(㎡)           float64
#  14  층                 float64
#  15  권리구분              object
#  16  취소일               float64
#  17  건축년도              float64
#  18  건물용도              object
#  19  신고구분              object
#  20  신고한 개업공인중개사 시군구명  object
# dtypes: float64(7), int64(5), object(9)
# memory usage: 424.0+ MB

# %%
df['접수연도'] = df['접수연도'].astype('int16')
df['건축년도'] = df['건축년도'].astype('float16')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2646181 entries, 0 to 2646180
# Data columns (total 21 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   접수연도              int16
#  1   자치구코드             int64
#  2   자치구명              object
#  3   법정동코드             int64
#  4   법정동명              object
#  5   지번구분              float64
#  6   지번구분명             object
#  7   본번                object
#  8   부번                float64
#  9   건물명               object
#  10  계약일               int64
#  11  물건금액(만원)          int64
#  12  건물면적(㎡)           float64
#  13  토지면적(㎡)           float64
#  14  층                 float64
#  15  권리구분              object
#  16  취소일               float64
#  17  건축년도              float16
#  18  건물용도              object
#  19  신고구분              object
#  20  신고한 개업공인중개사 시군구명  object
# dtypes: float16(1), float64(6), int16(1), int64(4), object(9)
# memory usage: 393.7+ MB

# %%
df.head()
# Out:
#    접수연도  자치구코드 자치구명  법정동코드 법정동명  지번구분 지번구분명     본번    부번       건물명  ...  \
# 0  2023  11500  강서구  10100  염창동   1.0    대지  294.0   0.0        길훈  ...
# 1  2023  11305  강북구  10300  수유동   1.0    대지  738.0   0.0  한원힐트리움수유  ...
# 2  2023  11500  강서구  10300  화곡동   1.0    대지  408.0  93.0  (408-93)  ...
# 3  2023  11530  구로구  10200  구로동   1.0    대지   98.0  12.0  파인마루오피스텔  ...
# 4  2023  11530  구로구  10200  구로동   1.0    대지  104.0   3.0      해담채3  ...
#
#    물건금액(만원)  건물면적(㎡)  토지면적(㎡)     층  권리구분 취소일    건축년도   건물용도  신고구분  \
# 0     65000    59.94     0.00   9.0   NaN NaN  1999.0    아파트  중개거래
# 1     23300    27.39     0.00   5.0   NaN NaN  2020.0    아파트  중개거래
# 2      9500    27.93    20.73  -1.0   NaN NaN  1986.0  연립다세대   직거래
# 3     15700    24.36    35.26   5.0   NaN NaN  2016.0   오피스텔  중개거래
# 4     12000    13.39     0.00  15.0   NaN NaN  2014.0    아파트  중개거래
#
#   신고한 개업공인중개사 시군구명
# 0           서울 강서구
# 1           서울 강북구
# 2              NaN
# 3   경기 하남시, 서울 구로구
# 4           서울 구로구
#
# [5 rows x 21 columns]

# %%
df['자치구명'].unique()
# Out:
# array(['강서구', '강북구', '구로구', '은평구', '동작구', '도봉구', '강동구', '양천구', '성북구',
#        '노원구', '마포구', '서대문구', '서초구', '중구', '용산구', '송파구', '광진구', '영등포구',
#        '종로구', '관악구', '동대문구', '중랑구', '강남구', '금천구', '성동구'], dtype=object)

# %%
len(df['자치구명'].unique())
# Out:
# 25

# %%
# 서초구의 데이터만 선택해서 df2를 생성
df2 = df[df['자치구명']=='서초구']

# %%
df2
# Out:
#          접수연도  자치구코드 자치구명  법정동코드 법정동명  지번구분 지번구분명      본번    부번           건물명  \
# 18       2023  11650  서초구  10800  서초동   1.0    대지  1445.0  14.0          더？서초
# 28       2023  11650  서초구  10800  서초동   1.0    대지  1445.0  14.0          더？서초
# 39       2023  11650  서초구  10800  서초동   1.0    대지  1674.0   5.0  하림인터내셔날 오피스텔
# 57       2023  11650  서초구  10800  서초동   1.0    대지  1469.0   6.0   서초아트빌(1469)
# 77       2023  11650  서초구  10100  방배동   1.0    대지   822.0  22.0       데코아트빌9차
# ...       ...    ...  ...    ...  ...   ...   ...     ...   ...           ...
# 2646145  2006  11650  서초구  10700  반포동   1.0    대지    70.0   1.0          한신서래
# 2646154  2006  11650  서초구  10800  서초동   1.0    대지  1333.0   0.0    신동아아파트(1차)
# 2646171  2006  11650  서초구  10100  방배동   1.0    대지  1018.0   1.0            삼익
# 2646172  2006  11650  서초구  10800  서초동   1.0    대지  1685.0   0.0         삼풍아파트
# 2646174  2006  11650  서초구  10600  잠원동   1.0    대지    73.0   0.0          신반포2
#
#          ...  물건금액(만원)  건물면적(㎡)  토지면적(㎡)     층  권리구분 취소일    건축년도   건물용도  신고구분  \
# 18       ...     38700    38.94    55.32   7.0   NaN NaN  2006.0   오피스텔   직거래
# 28       ...     38700    38.94    55.32   7.0   NaN NaN  2006.0   오피스텔   직거래
# 39       ...     29500    24.12    40.19  10.0   NaN NaN  2013.0   오피스텔  중개거래
# 57       ...     70000    74.94    44.33   3.0   NaN NaN  2002.0  연립다세대  중개거래
# 77       ...     53000    26.50    18.20   3.0   NaN NaN  2021.0  연립다세대   직거래
# ...      ...       ...      ...      ...   ...   ...  ..     ...    ...   ...
# 2646145  ...     24000    45.72      NaN   2.0   NaN NaN  1987.0    아파트   NaN
# 2646154  ...     45200    75.86      NaN  10.0   NaN NaN  1978.0    아파트   NaN
# 2646171  ...     51500    89.12      NaN   7.0   NaN NaN  1981.0    아파트   NaN
# 2646172  ...     74000    79.47      NaN   6.0   NaN NaN  1988.0    아파트   NaN
# 2646174  ...     56700    79.42      NaN   4.0   NaN NaN  1978.0    아파트   NaN
#
#         신고한 개업공인중개사 시군구명
# 18                   NaN
# 28                   NaN
# 39                서울 서초구
# 57                서울 서초구
# 77                   NaN
# ...                  ...
# 2646145              NaN
# 2646154              NaN
# 2646171              NaN
# 2646172              NaN
# 2646174              NaN
#
# [105233 rows x 21 columns]

# %%
df2['접수연도'].unique()
# Out:
# array([2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013,
#        2012, 2011, 2010, 2009, 2008, 2007, 2006], dtype=int16)

# %%
df2['건물용도'].unique()
# Out:
# array(['오피스텔', '연립다세대', '아파트', '단독다가구'], dtype=object)

# %%
apt_df2 = df2[df2['건물용도']=='아파트']

# %%
# 서초구의 아파트의 데이터 갯수는 62884
# 접수년도별로 데이터는 몇개씩 일까요?
len(apt_df2)
# Out:
# 62884

# %%
apt_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 62884 entries, 156 to 2646174
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   접수연도              62884 non-null  int16
#  1   자치구코드             62884 non-null  int64
#  2   자치구명              62884 non-null  object
#  3   법정동코드             62884 non-null  int64
#  4   법정동명              62884 non-null  object
#  5   지번구분              62757 non-null  float64
#  6   지번구분명             62757 non-null  object
#  7   본번                62757 non-null  object
#  8   부번                62757 non-null  float64
#  9   건물명               62884 non-null  object
#  10  계약일               62884 non-null  int64
#  11  물건금액(만원)          62884 non-null  int64
#  12  건물면적(㎡)           62884 non-null  float64
#  13  토지면적(㎡)           18039 non-null  float64
#  14  층                 62884 non-null  float64
#  15  권리구분              1950 non-null   object
#  16  취소일               1095 non-null   float64
#  17  건축년도              62884 non-null  float16
#  18  건물용도              62884 non-null  object
#  19  신고구분              2750 non-null   object
#  20  신고한 개업공인중개사 시군구명  2349 non-null   object
# dtypes: float16(1), float64(6), int16(1), int64(4), object(9)
# memory usage: 9.8+ MB

# %%
apt_df2.sort_values(by='접수연도', inplace=True)
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_5456\741880197.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apt_df2.sort_values(by='접수연도', inplace=True)

# %%
apt_df2
# Out:
#          접수연도  자치구코드 자치구명  법정동코드 법정동명  지번구분 지번구분명      본번    부번        건물명  \
# 2646174  2006  11650  서초구  10600  잠원동   1.0    대지    73.0   0.0       신반포2
# 2645917  2006  11650  서초구  10600  잠원동   1.0    대지    58.0  16.0      신반포10
# 2645976  2006  11650  서초구  10600  잠원동   1.0    대지    60.0   3.0       신반포8
# 2591287  2006  11650  서초구  10800  서초동   1.0    대지  1310.0   0.0       삼호1차
# 2645921  2006  11650  서초구  10600  잠원동   1.0    대지    73.0   0.0       신반포2
# ...       ...    ...  ...    ...  ...   ...   ...     ...   ...        ...
# 710      2023  11650  서초구  10800  서초동   1.0    대지  1338.0   1.0   풍림아이원플러스
# 441      2023  11650  서초구  10700  반포동   1.0    대지    20.0  43.0       반포자이
# 5169     2023  11650  서초구  10100  방배동   1.0    대지   847.0  34.0  방배대우유로카운티
# 2463     2023  11650  서초구  10100  방배동   1.0    대지  3278.0   0.0     방배아트자이
# 156      2023  11650  서초구  10800  서초동   1.0    대지  1496.0   6.0    루컴즈힐서리풀
#
#          ...  물건금액(만원)  건물면적(㎡)  토지면적(㎡)     층  권리구분 취소일    건축년도  건물용도  신고구분  \
# 2646174  ...     56700    79.42      NaN   4.0   NaN NaN  1978.0   아파트   NaN
# 2645917  ...     48000    77.10      NaN   1.0   NaN NaN  1981.0   아파트   NaN
# 2645976  ...     33300    52.74      NaN  12.0   NaN NaN  1981.0   아파트   NaN
# 2591287  ...    135000   140.79      NaN   9.0   NaN NaN  1979.0   아파트   NaN
# 2645921  ...     72000    79.42      NaN   3.0   NaN NaN  1978.0   아파트   NaN
# ...      ...       ...      ...      ...   ...   ...  ..     ...   ...   ...
# 710      ...     36000    35.90      0.0  10.0   NaN NaN  2004.0   아파트  중개거래
# 441      ...    530000   194.52      0.0  17.0   NaN NaN  2009.0   아파트  중개거래
# 5169     ...    280000   202.40      0.0  10.0   NaN NaN  2002.0   아파트  중개거래
# 2463     ...    155000    59.99      0.0   6.0   NaN NaN  2018.0   아파트  중개거래
# 156      ...    150000    78.77      0.0   7.0   NaN NaN  2020.0   아파트   직거래
#
#         신고한 개업공인중개사 시군구명
# 2646174              NaN
# 2645917              NaN
# 2645976              NaN
# 2591287              NaN
# 2645921              NaN
# ...                  ...
# 710               서울 서초구
# 441               서울 서초구
# 5169              서울 서초구
# 2463              서울 서초구
# 156                  NaN
#
# [62884 rows x 21 columns]

# %%
apt_df2['접수연도'].value_counts()
# Out:
# 2023     117
# 2007    1757
# 2012    1921
# 2008    2028
# 2022    2497
# 2021    2569
# 2011    2915
# 2019    2959
# 2010    3207
# 2013    3228
# 2018    3576
# 2020    3767
# 2014    5076
# 2017    5253
# 2016    5353
# 2009    5406
# 2006    5441
# 2015    5814
# Name: 접수연도, dtype: int64

# %%
apt_df2['건물명'].value_counts()
# Out:
# 반포자이            2527
# 래미안퍼스티지         1590
# 삼풍아파트           1247
# 신반포2            1031
# 에이아이디차관주택        947
#                 ...
# 그린씨티아파트1           1
# 방배아트e편한세상105       1
# 블루힐65              1
# 효성빌라26동            1
# 루컴즈힐서리풀            1
# Name: 건물명, Length: 848, dtype: int64

# %%
# 가장 데이터가 많은 '반포자이'(2527건)를 기준으로 층별 가격차이가 발생하는지 확인
# 입주권은 물건금액의 차이가 발생하므로 아파트가격 상승 검토시 삭제해야하는가?
#

# %%
apt_xi_df2 = apt_df2[apt_df2['건물명']=='반포자이']

# %%
apt_xi_df2
# Out:
#          접수연도  자치구코드 자치구명  법정동코드 법정동명  지번구분 지번구분명    본번    부번   건물명  ...  \
# 2351312  2007  11650  서초구  10700  반포동   1.0    대지  20.0  43.0  반포자이  ...
# 2339170  2007  11650  서초구  10700  반포동   1.0    대지  20.0  43.0  반포자이  ...
# 2337548  2007  11650  서초구  10700  반포동   1.0    대지  20.0  43.0  반포자이  ...
# 2331049  2007  11650  서초구  10700  반포동   1.0    대지  20.0  43.0  반포자이  ...
# 2306102  2007  11650  서초구  10700  반포동   1.0    대지  20.0  43.0  반포자이  ...
# ...       ...    ...  ...    ...  ...   ...   ...   ...   ...   ...  ...
# 10573    2023  11650  서초구  10700  반포동   1.0    대지  20.0  43.0  반포자이  ...
# 6989     2023  11650  서초구  10700  반포동   1.0    대지  20.0  43.0  반포자이  ...
# 5916     2023  11650  서초구  10700  반포동   1.0    대지  20.0  43.0  반포자이  ...
# 3753     2023  11650  서초구  10700  반포동   1.0    대지  20.0  43.0  반포자이  ...
# 441      2023  11650  서초구  10700  반포동   1.0    대지  20.0  43.0  반포자이  ...
#
#          물건금액(만원)  건물면적(㎡)  토지면적(㎡)     층  권리구분 취소일    건축년도  건물용도  신고구분  \
# 2351312    277500   244.97      0.0  24.0   입주권 NaN     0.0   아파트   NaN
# 2339170    281383   194.52      0.0  20.0   입주권 NaN     0.0   아파트   NaN
# 2337548    122000    84.94      0.0  15.0   입주권 NaN     0.0   아파트   NaN
# 2331049    256500   244.54      0.0  12.0   입주권 NaN     0.0   아파트   NaN
# 2306102    225000   194.52      0.0   7.0   입주권 NaN     0.0   아파트   NaN
# ...           ...      ...      ...   ...   ...  ..     ...   ...   ...
# 10573      510000   165.45      0.0  14.0   NaN NaN  2009.0   아파트  중개거래
# 6989       235000    59.98      0.0  12.0   NaN NaN  2009.0   아파트  중개거래
# 5916       284000    84.98      0.0  21.0   NaN NaN  2009.0   아파트  중개거래
# 3753       297000    84.94      0.0  26.0   NaN NaN  2009.0   아파트  중개거래
# 441        530000   194.52      0.0  17.0   NaN NaN  2009.0   아파트  중개거래
#
#         신고한 개업공인중개사 시군구명
# 2351312              NaN
# 2339170              NaN
# 2337548              NaN
# 2331049              NaN
# 2306102              NaN
# ...                  ...
# 10573             서울 서초구
# 6989      서울 강남구, 서울 서초구
# 5916              서울 서초구
# 3753              서울 서초구
# 441               서울 서초구
#
# [2527 rows x 21 columns]

# %%
apt_xi_df2['신고구분'].unique()
# Out:
# array([nan, '중개거래'], dtype=object)

# %%
# [과제] apt_xi_df2 데이터프레임의 결측치 데이터를 해결해 봅시다.

# %%
# '신고구분'에 NaN값인 경우 '권리구분'이 모두 입주권인가?

# %%
# '권리구분'이 NaN인 경우 모두 중개거래인가?

# %%
# '신고한 개업공인중개사 시군구명'이 NaN인 경우 모두 '권리구분'이 입주권인가?
