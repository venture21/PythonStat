# %%
import pandas as pd

# csv파일 가져오기
#csvFile = 'C:/Users/student/Documents/GitHub/PythonStat/data/대한민국인구10년통계.csv'

#github에 저장된 CSV파일 불러오기
#https://velog.io/@countifs/%EC%BD%94%EB%9E%A9%EC%97%90%EC%84%9C-github-csv%ED%8C%8C%EC%9D%BC-%EB%B6%88%EB%9F%AC%EC%98%A4%EA%B8%B0
csvFile = 'https://raw.githubusercontent.com/venture21/PythonStat/main/data/%EB%8C%80%ED%95%9C%EB%AF%BC%EA%B5%AD%EC%9D%B8%EA%B5%AC10%EB%85%84%ED%86%B5%EA%B3%84.csv'

df = pd.read_csv(csvFile, encoding='cp949')

# %%
df.columns
# Out:
# Index(['행정구역(시군구)별', '2022.12', '2022.12.1', '2022.12.2', '2023.01',
#        '2023.01.1', '2023.01.2', '2023.02', '2023.02.1', '2023.02.2', '2013',
#        '2013.1', '2013.2', '2014', '2014.1', '2014.2', '2015', '2015.1',
#        '2015.2', '2016', '2016.1', '2016.2', '2017', '2017.1', '2017.2',
#        '2018', '2018.1', '2018.2', '2019', '2019.1', '2019.2', '2020',
#        '2020.1', '2020.2', '2021', '2021.1', '2021.2', '2022', '2022.1',
#        '2022.2'],
#       dtype='object')

# %%
delColList = ['2022.12', '2022.12.1', '2022.12.2', '2023.01','2023.01.1', '2023.01.2', '2023.02', '2023.02.1', '2023.02.2']
df.drop(delColList, axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 31 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   행정구역(시군구)별  19 non-null     object
#  1   2013        19 non-null     object
#  2   2013.1      19 non-null     object
#  3   2013.2      19 non-null     object
#  4   2014        19 non-null     object
#  5   2014.1      19 non-null     object
#  6   2014.2      19 non-null     object
#  7   2015        19 non-null     object
#  8   2015.1      19 non-null     object
#  9   2015.2      19 non-null     object
#  10  2016        19 non-null     object
#  11  2016.1      19 non-null     object
#  12  2016.2      19 non-null     object
#  13  2017        19 non-null     object
#  14  2017.1      19 non-null     object
#  15  2017.2      19 non-null     object
#  16  2018        19 non-null     object
#  17  2018.1      19 non-null     object
#  18  2018.2      19 non-null     object
#  19  2019        19 non-null     object
#  20  2019.1      19 non-null     object
#  21  2019.2      19 non-null     object
#  22  2020        19 non-null     object
#  23  2020.1      19 non-null     object
#  24  2020.2      19 non-null     object
#  25  2021        19 non-null     object
#  26  2021.1      19 non-null     object
#  27  2021.2      19 non-null     object
#  28  2022        19 non-null     object
#  29  2022.1      19 non-null     object
#  30  2022.2      19 non-null     object
# dtypes: object(31)
# memory usage: 4.7+ KB

# %%
df.head()
# Out:
#    행정구역(시군구)별      2013     2013.1     2013.2      2014     2014.1     2014.2  \
# 0  행정구역(시군구)별  총인구수 (명)  남자인구수 (명)  여자인구수 (명)  총인구수 (명)  남자인구수 (명)  여자인구수 (명)
# 1          전국  51141463   25588336   25553127  51327916   25669296   25658620
# 2       서울특별시  10143645    5007869    5135776  10103233    4979768    5123465
# 3       부산광역시   3527635    1747000    1780635   3519401    1740417    1778984
# 4       대구광역시   2501588    1246071    1255517   2493264    1241119    1252145
#
#        2015     2015.1     2015.2  ...     2019.2      2020     2020.1  \
# 0  총인구수 (명)  남자인구수 (명)  여자인구수 (명)  ...  여자인구수 (명)  총인구수 (명)  남자인구수 (명)
# 1  51529338   25758186   25771152  ...   25985045  51829023   25841029
# 2  10022181    4930943    5091238  ...    4985048   9668465    4701723
# 3   3513777    1735570    1778207  ...    1738424   3391946    1661000
# 4   2487829    1237291    1250538  ...    1232745   2418346    1193109
#
#       2020.2      2021     2021.1     2021.2      2022     2022.1     2022.2
# 0  여자인구수 (명)  총인구수 (명)  남자인구수 (명)  여자인구수 (명)  총인구수 (명)  남자인구수 (명)  여자인구수 (명)
# 1   25987994  51638809   25746684   25892125  51439038   25636951   25802087
# 2    4966742   9509458    4618040    4891418   9428372    4570048    4858324
# 3    1730946   3350380    1639044    1711336   3317812    1619915    1697897
# 4    1225237   2385412    1175632    1209780   2363691    1162865    1200826
#
# [5 rows x 31 columns]

# %%
# 0번 행을 컬럼명으로 변경하기
df = df.rename(columns=df.iloc[0])
df.drop(0, inplace=True)

# %%
df.head()
# Out:
#   행정구역(시군구)별  총인구수 (명) 남자인구수 (명) 여자인구수 (명)  총인구수 (명) 남자인구수 (명) 여자인구수 (명)  \
# 1         전국  51141463  25588336  25553127  51327916  25669296  25658620
# 2      서울특별시  10143645   5007869   5135776  10103233   4979768   5123465
# 3      부산광역시   3527635   1747000   1780635   3519401   1740417   1778984
# 4      대구광역시   2501588   1246071   1255517   2493264   1241119   1252145
# 5      인천광역시   2879782   1448835   1430947   2902608   1459074   1443534
#
#    총인구수 (명) 남자인구수 (명) 여자인구수 (명)  ... 여자인구수 (명)  총인구수 (명) 남자인구수 (명) 여자인구수 (명)  \
# 1  51529338  25758186  25771152  ...  25985045  51829023  25841029  25987994
# 2  10022181   4930943   5091238  ...   4985048   9668465   4701723   4966742
# 3   3513777   1735570   1778207  ...   1738424   3391946   1661000   1730946
# 4   2487829   1237291   1250538  ...   1232745   2418346   1193109   1225237
# 5   2925815   1469869   1455946  ...   1474777   2942828   1473943   1468885
#
#    총인구수 (명) 남자인구수 (명) 여자인구수 (명)  총인구수 (명) 남자인구수 (명) 여자인구수 (명)
# 1  51638809  25746684  25892125  51439038  25636951  25802087
# 2   9509458   4618040   4891418   9428372   4570048   4858324
# 3   3350380   1639044   1711336   3317812   1619915   1697897
# 4   2385412   1175632   1209780   2363691   1162865   1200826
# 5   2948375   1476373   1472002   2967314   1485175   1482139
#
# [5 rows x 31 columns]

# %%
# 년도가 표기되어 있지 않은 컬럼명을 읽어온다.
df.columns
# Out:
# Index(['행정구역(시군구)별', '총인구수 (명)', '남자인구수 (명)', '여자인구수 (명)', '총인구수 (명)',
#        '남자인구수 (명)', '여자인구수 (명)', '총인구수 (명)', '남자인구수 (명)', '여자인구수 (명)',
#        '총인구수 (명)', '남자인구수 (명)', '여자인구수 (명)', '총인구수 (명)', '남자인구수 (명)',
#        '여자인구수 (명)', '총인구수 (명)', '남자인구수 (명)', '여자인구수 (명)', '총인구수 (명)',
#        '남자인구수 (명)', '여자인구수 (명)', '총인구수 (명)', '남자인구수 (명)', '여자인구수 (명)',
#        '총인구수 (명)', '남자인구수 (명)', '여자인구수 (명)', '총인구수 (명)', '남자인구수 (명)',
#        '여자인구수 (명)'],
#       dtype='object')

# %%
# 앞의 셀에서 df.columns값을 복사해서 가져온다(Ctrl+c & Ctrl+v)
tempList = ['행정구역(시군구)별', '총인구수 (명)', '남자인구수 (명)', '여자인구수 (명)', '총인구수 (명)',
       '남자인구수 (명)', '여자인구수 (명)', '총인구수 (명)', '남자인구수 (명)', '여자인구수 (명)',
       '총인구수 (명)', '남자인구수 (명)', '여자인구수 (명)', '총인구수 (명)', '남자인구수 (명)',
       '여자인구수 (명)', '총인구수 (명)', '남자인구수 (명)', '여자인구수 (명)', '총인구수 (명)',
       '남자인구수 (명)', '여자인구수 (명)', '총인구수 (명)', '남자인구수 (명)', '여자인구수 (명)',
       '총인구수 (명)', '남자인구수 (명)', '여자인구수 (명)', '총인구수 (명)', '남자인구수 (명)',
       '여자인구수 (명)']

# %%
# 괄호안의 문자열을 삭제하는 코드
import re

pattern = r'\([^)]*\)'
x = '이건 (괄호 안의 불필요한 정보를) 삭제하는 코드다.'

text = re.sub(pattern=pattern, repl='', string= x)
print(text)

# 문자열에서 공백을 기준으로 나누어주는 함수
text.split()
# Out:
# 이건  삭제하는 코드다.
# ['이건', '삭제하는', '코드다.']

# %%
# [문제안에 문제]
# tempList에서 '(~~~)'내용 삭제하기 + 문자열안에 공백(strip()함수를 사용)이 있다면 공백 삭제하기
import re

newColName =[]

pattern = r'\([^)]*\)'
year = 2012


# 한번에 for문의 로직을 생각하지 말고
# 1. 괄호안에 있는 내용 삭제하기
# 2. 문자열 안에 공백 삭제
# 3. 연도가 삭제된 상태, 그래서 연도를 추가
# 4. 0번 리스트를 연도를 추가하면 안됨

for i, word in enumerate(tempList):
    text = re.sub(pattern=pattern, repl='', string= word)
    #print("정규식결과:{}".format(text))
    text = text.strip()

    if i%3==1:
        year+=1

    #처음 리스트만 제외
    if i!=0:
        text = str(year) + ' ' + text
        
    #print("{}, 문자열결과:{}".format(i, text))
    newColName.append(text)

# %%
newColName
# Out:
# ['행정구역별',
#  '2013 총인구수',
#  '2013 남자인구수',
#  '2013 여자인구수',
#  '2014 총인구수',
#  '2014 남자인구수',
#  '2014 여자인구수',
#  '2015 총인구수',
#  '2015 남자인구수',
#  '2015 여자인구수',
#  '2016 총인구수',
#  '2016 남자인구수',
#  '2016 여자인구수',
#  '2017 총인구수',
#  '2017 남자인구수',
#  '2017 여자인구수',
#  '2018 총인구수',
#  '2018 남자인구수',
#  '2018 여자인구수',
#  '2019 총인구수',
#  '2019 남자인구수',
#  '2019 여자인구수',
#  '2020 총인구수',
#  '2020 남자인구수',
#  '2020 여자인구수',
#  '2021 총인구수',
#  '2021 남자인구수',
#  '2021 여자인구수',
#  '2022 총인구수',
#  '2022 남자인구수',
#  '2022 여자인구수']

# %%
df.columns = newColName

# %%
df.columns
# Out:
# Index(['행정구역별', '2013 총인구수', '2013 남자인구수', '2013 여자인구수', '2014 총인구수',
#        '2014 남자인구수', '2014 여자인구수', '2015 총인구수', '2015 남자인구수', '2015 여자인구수',
#        '2016 총인구수', '2016 남자인구수', '2016 여자인구수', '2017 총인구수', '2017 남자인구수',
#        '2017 여자인구수', '2018 총인구수', '2018 남자인구수', '2018 여자인구수', '2019 총인구수',
#        '2019 남자인구수', '2019 여자인구수', '2020 총인구수', '2020 남자인구수', '2020 여자인구수',
#        '2021 총인구수', '2021 남자인구수', '2021 여자인구수', '2022 총인구수', '2022 남자인구수',
#        '2022 여자인구수'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 1 to 18
# Data columns (total 31 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   행정구역별       18 non-null     object
#  1   2013 총인구수   18 non-null     object
#  2   2013 남자인구수  18 non-null     object
#  3   2013 여자인구수  18 non-null     object
#  4   2014 총인구수   18 non-null     object
#  5   2014 남자인구수  18 non-null     object
#  6   2014 여자인구수  18 non-null     object
#  7   2015 총인구수   18 non-null     object
#  8   2015 남자인구수  18 non-null     object
#  9   2015 여자인구수  18 non-null     object
#  10  2016 총인구수   18 non-null     object
#  11  2016 남자인구수  18 non-null     object
#  12  2016 여자인구수  18 non-null     object
#  13  2017 총인구수   18 non-null     object
#  14  2017 남자인구수  18 non-null     object
#  15  2017 여자인구수  18 non-null     object
#  16  2018 총인구수   18 non-null     object
#  17  2018 남자인구수  18 non-null     object
#  18  2018 여자인구수  18 non-null     object
#  19  2019 총인구수   18 non-null     object
#  20  2019 남자인구수  18 non-null     object
#  21  2019 여자인구수  18 non-null     object
#  22  2020 총인구수   18 non-null     object
#  23  2020 남자인구수  18 non-null     object
#  24  2020 여자인구수  18 non-null     object
#  25  2021 총인구수   18 non-null     object
#  26  2021 남자인구수  18 non-null     object
#  27  2021 여자인구수  18 non-null     object
#  28  2022 총인구수   18 non-null     object
#  29  2022 남자인구수  18 non-null     object
#  30  2022 여자인구수  18 non-null     object
# dtypes: object(31)
# memory usage: 4.5+ KB

# %%
# df['행정구역별']컬럼만 제외하고 나머지 컬럼 데이터는 모두 int로 변경
df2 = df.iloc[:,1:].astype('int')

# %%
# insert함수의 1st:컬럼이 들어갈 위치 index, 2nd : 추가할 컬럼의 이름, 3rd:컬럼에 추가될 데이터 
df2.insert(0, '행정구역별', df['행정구역별'])

# %%
df2['행정구역별']
# Out:
# 1          전국
# 2       서울특별시
# 3       부산광역시
# 4       대구광역시
# 5       인천광역시
# 6       광주광역시
# 7       대전광역시
# 8       울산광역시
# 9     세종특별자치시
# 10        경기도
# 11        강원도
# 12       충청북도
# 13       충청남도
# 14       전라북도
# 15       전라남도
# 16       경상북도
# 17       경상남도
# 18    제주특별자치도
# Name: 행정구역별, dtype: object

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 1 to 18
# Data columns (total 31 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   행정구역별       18 non-null     object
#  1   2013 총인구수   18 non-null     int32
#  2   2013 남자인구수  18 non-null     int32
#  3   2013 여자인구수  18 non-null     int32
#  4   2014 총인구수   18 non-null     int32
#  5   2014 남자인구수  18 non-null     int32
#  6   2014 여자인구수  18 non-null     int32
#  7   2015 총인구수   18 non-null     int32
#  8   2015 남자인구수  18 non-null     int32
#  9   2015 여자인구수  18 non-null     int32
#  10  2016 총인구수   18 non-null     int32
#  11  2016 남자인구수  18 non-null     int32
#  12  2016 여자인구수  18 non-null     int32
#  13  2017 총인구수   18 non-null     int32
#  14  2017 남자인구수  18 non-null     int32
#  15  2017 여자인구수  18 non-null     int32
#  16  2018 총인구수   18 non-null     int32
#  17  2018 남자인구수  18 non-null     int32
#  18  2018 여자인구수  18 non-null     int32
#  19  2019 총인구수   18 non-null     int32
#  20  2019 남자인구수  18 non-null     int32
#  21  2019 여자인구수  18 non-null     int32
#  22  2020 총인구수   18 non-null     int32
#  23  2020 남자인구수  18 non-null     int32
#  24  2020 여자인구수  18 non-null     int32
#  25  2021 총인구수   18 non-null     int32
#  26  2021 남자인구수  18 non-null     int32
#  27  2021 여자인구수  18 non-null     int32
#  28  2022 총인구수   18 non-null     int32
#  29  2022 남자인구수  18 non-null     int32
#  30  2022 여자인구수  18 non-null     int32
# dtypes: int32(30), object(1)
# memory usage: 2.4+ KB

# %%
#방법 2
import matplotlib.pyplot as plt

# plt.rc('font', family='NanumMyeongjoOTF') # For MacOS
# print(plt.rcParams['font.family'])

plt.rc('font', family='gulim') # For Windows
print(plt.rcParams['font.family'])
# Out:
# ['gulim']

# %%
# 이렇게 정리된 데이터를 가지고
# 년도별 총 인구수를 기반으로 지역별 인구 변화를 bar chart로 확인
# 가로:행정구역별
df2.plot.barh(x='행정구역별', y='2013 총인구수', rot=0)
# Out:
# <Axes: ylabel='행정구역별'>

# %%
colList = []

year = 2013
for colyear in range(year, year+10):
    name = str(colyear)+' '+'총인구수'
    colList.append(name)

print(colList)

for colName in colList:
    df2.plot.barh(x='행정구역별', y=colName, rot=0)
# Out:
# ['2013 총인구수', '2014 총인구수', '2015 총인구수', '2016 총인구수', '2017 총인구수', '2018 총인구수', '2019 총인구수', '2020 총인구수', '2021 총인구수', '2022 총인구수']

# %%
# 서울특별시만 2013~2022년까지 모아서 비교하기 위해 그래프
df2
# Out:
#       행정구역별  2013 총인구수  2013 남자인구수  2013 여자인구수  2014 총인구수  2014 남자인구수  \
# 1        전국   51141463    25588336    25553127   51327916    25669296
# 2     서울특별시   10143645     5007869     5135776   10103233     4979768
# 3     부산광역시    3527635     1747000     1780635    3519401     1740417
# 4     대구광역시    2501588     1246071     1255517    2493264     1241119
# 5     인천광역시    2879782     1448835     1430947    2902608     1459074
# 6     광주광역시    1472910      730216      742694    1475884      731339
# 7     대전광역시    1532811      767309      765502    1531809      766497
# 8     울산광역시    1156480      595319      561161    1166377      600904
# 9   세종특별자치시     122153       62205       59948     156125       78862
# 10      경기도   12234630     6159193     6075437   12357830     6219813
# 11      강원도    1542263      776498      765765    1544442      778007
# 12     충청북도    1572732      792862      779870    1578933      796141
# 13     충청남도    2047631     1037421     1010210    2062273     1045892
# 14     전라북도    1872965      932894      940071    1871560      931536
# 15     전라남도    1907172      952597      954575    1905780      951975
# 16     경상북도    2699440     1355951     1343489    2700794     1356182
# 17     경상남도    3333820     1678592     1655228    3350257     1687114
# 18  제주특별자치도     593806      297504      296302     607346      304656
#
#     2014 여자인구수  2015 총인구수  2015 남자인구수  2015 여자인구수  ...  2019 여자인구수  2020 총인구수  \
# 1     25658620   51529338    25758186    25771152  ...    25985045   51829023
# 2      5123465   10022181     4930943     5091238  ...     4985048    9668465
# 3      1778984    3513777     1735570     1778207  ...     1738424    3391946
# 4      1252145    2487829     1237291     1250538  ...     1232745    2418346
# 5      1443534    2925815     1469869     1455946  ...     1474777    2942828
# 6       744545    1472199      729662      742537  ...      735728    1450062
# 7       765312    1518775      759778      758997  ...      738263    1463882
# 8       565473    1173534      604889      568645  ...      558307    1136017
# 9        77263     210884      105752      105132  ...      170730     355831
# 10     6138017   12522606     6299812     6222794  ...     6579671   13427014
# 11      766435    1549507      781434      768073  ...      766116    1542840
# 12      782792    1583952      798896      785056  ...      789623    1600837
# 13     1016381    2077649     1054439     1023210  ...     1041771    2121029
# 14      940024    1869711      930255      939456  ...      914807    1804104
# 15      953805    1908996      953881      955115  ...      931071    1851549
# 16     1344612    2702826     1357306     1345520  ...     1323799    2639422
# 17     1663143    3364702     1694981     1669721  ...     1670521    3340216
# 18      302690     624395      313428      310967  ...      333644     674635
#
#     2020 남자인구수  2020 여자인구수  2021 총인구수  2021 남자인구수  2021 여자인구수  2022 총인구수  \
# 1     25841029    25987994   51638809    25746684    25892125   51439038
# 2      4701723     4966742    9509458     4618040     4891418    9428372
# 3      1661000     1730946    3350380     1639044     1711336    3317812
# 4      1193109     1225237    2385412     1175632     1209780    2363691
# 5      1473943     1468885    2948375     1476373     1472002    2967314
# 6       717348      732714    1441611      713015      728596    1431050
# 7       730699      733183    1452251      724626      727625    1446072
# 8       583708      552309    1121592      576217      545375    1110663
# 9       177568      178263     371895      185678      186217     383591
# 10     6754469     6672545   13565450     6827298     6738152   13589432
# 11      776505      766335    1538492      774332      764160    1536498
# 12      811591      789246    1597427      810672      786755    1595058
# 13     1082634     1038395    2119257     1083366     1035891    2123037
# 14      896874      907230    1786855      888994      897861    1769607
# 15      930615      920934    1832803      922221      910582    1817697
# 16     1329211     1310211    2626609     1323661     1302948    2600492
# 17     1681423     1658793    3314183     1668338     1645845    3280493
# 18      338609      336026     676759      339177      337582     678159
#
#     2022 남자인구수  2022 여자인구수
# 1     25636951    25802087
# 2      4570048     4858324
# 3      1619915     1697897
# 4      1162865     1200826
# 5      1485175     1482139
# 6       707299      723751
# 7       721245      724827
# 8       570368      540295
# 9       191389      192202
# 10     6839276     6750156
# 11      772947      763551
# 12      810782      784276
# 13     1086632     1036405
# 14      880592      889015
# 15      915272      902425
# 16     1311881     1288611
# 17     1651675     1628818
# 18      339590      338569
#
# [18 rows x 31 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 1 to 18
# Data columns (total 31 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   행정구역별       18 non-null     object
#  1   2013 총인구수   18 non-null     int32
#  2   2013 남자인구수  18 non-null     int32
#  3   2013 여자인구수  18 non-null     int32
#  4   2014 총인구수   18 non-null     int32
#  5   2014 남자인구수  18 non-null     int32
#  6   2014 여자인구수  18 non-null     int32
#  7   2015 총인구수   18 non-null     int32
#  8   2015 남자인구수  18 non-null     int32
#  9   2015 여자인구수  18 non-null     int32
#  10  2016 총인구수   18 non-null     int32
#  11  2016 남자인구수  18 non-null     int32
#  12  2016 여자인구수  18 non-null     int32
#  13  2017 총인구수   18 non-null     int32
#  14  2017 남자인구수  18 non-null     int32
#  15  2017 여자인구수  18 non-null     int32
#  16  2018 총인구수   18 non-null     int32
#  17  2018 남자인구수  18 non-null     int32
#  18  2018 여자인구수  18 non-null     int32
#  19  2019 총인구수   18 non-null     int32
#  20  2019 남자인구수  18 non-null     int32
#  21  2019 여자인구수  18 non-null     int32
#  22  2020 총인구수   18 non-null     int32
#  23  2020 남자인구수  18 non-null     int32
#  24  2020 여자인구수  18 non-null     int32
#  25  2021 총인구수   18 non-null     int32
#  26  2021 남자인구수  18 non-null     int32
#  27  2021 여자인구수  18 non-null     int32
#  28  2022 총인구수   18 non-null     int32
#  29  2022 남자인구수  18 non-null     int32
#  30  2022 여자인구수  18 non-null     int32
# dtypes: int32(30), object(1)
# memory usage: 2.4+ KB

# %%
import matplotlib.pyplot as plt

#'년도'+' '+'총인구수' 이런 컬럼만 골라내려면
# 3x-2

# 그래프의 X 데이터 생성
start=2013
period =10

x = []
for year in range(start,start+period):
     x.append(year)

# 그래프의 Y데이터 생성
popData = []
for i in range(1, len(df2.columns), 3):
    Seoul.append(df2.iloc[1, i])
  
plt.bar(x, popData)
# Out:
# <BarContainer object of 10 artists>

# %%
df.head()
# Out:
#    행정구역별 2013 총인구수 2013 남자인구수 2013 여자인구수 2014 총인구수 2014 남자인구수 2014 여자인구수  \
# 1     전국  51141463   25588336   25553127  51327916   25669296   25658620
# 2  서울특별시  10143645    5007869    5135776  10103233    4979768    5123465
# 3  부산광역시   3527635    1747000    1780635   3519401    1740417    1778984
# 4  대구광역시   2501588    1246071    1255517   2493264    1241119    1252145
# 5  인천광역시   2879782    1448835    1430947   2902608    1459074    1443534
#
#   2015 총인구수 2015 남자인구수 2015 여자인구수  ... 2019 여자인구수 2020 총인구수 2020 남자인구수  \
# 1  51529338   25758186   25771152  ...   25985045  51829023   25841029
# 2  10022181    4930943    5091238  ...    4985048   9668465    4701723
# 3   3513777    1735570    1778207  ...    1738424   3391946    1661000
# 4   2487829    1237291    1250538  ...    1232745   2418346    1193109
# 5   2925815    1469869    1455946  ...    1474777   2942828    1473943
#
#   2020 여자인구수 2021 총인구수 2021 남자인구수 2021 여자인구수 2022 총인구수 2022 남자인구수 2022 여자인구수
# 1   25987994  51638809   25746684   25892125  51439038   25636951   25802087
# 2    4966742   9509458    4618040    4891418   9428372    4570048    4858324
# 3    1730946   3350380    1639044    1711336   3317812    1619915    1697897
# 4    1225237   2385412    1175632    1209780   2363691    1162865    1200826
# 5    1468885   2948375    1476373    1472002   2967314    1485175    1482139
#
# [5 rows x 31 columns]

# %%
# 데이터프레임에서 총인구수 컬럼만 리스트로 생성해주는 함수
def makeTotalPopList():
    colList = []

    year = 2013
    period = 10
    for colyear in range(year, year+period):
        name = str(colyear)+' '+'총인구수'
        colList.append(name)

    return colList

def drawChart(localName, totalPopList):
    local_df = df2[df2['행정구역별']==localName][totalPopList]
    print(local_df)
    
    df2.plot.barh(x=df2.columns, y=df2.loc[:,:], rot=0)


# #     # 그래프의 Y데이터 생성
#     popData = []
#     for i in range(1, len(df2.columns), 3):
#         Seoul.append(df2.iloc[1, i])    


totalPopList = makeTotalPopList()

#print(totalPopList)

drawChart('서울특별시', totalPopList)
# Out:
#    2013 총인구수  2014 총인구수  2015 총인구수  2016 총인구수  2017 총인구수  2018 총인구수  \
# 2   10143645   10103233   10022181    9930616    9857426    9765623
#
#    2019 총인구수  2020 총인구수  2021 총인구수  2022 총인구수
# 2    9729107    9668465    9509458    9428372
# --------------------------------------------------------------------------
# ValueError                               Traceback (most recent call last)
# Cell In[56], line 30
#      26 totalPopList = makeTotalPopList()
#      28 #print(totalPopList)
# ---> 30 drawChart('서울특별시', totalPopList)
#
# Cell In[56], line 17, in drawChart(localName, totalPopList)
#      14 local_df = df2[df2['행정구역별']==localName][totalPopList]
#      15 print(local_df)
# ---> 17 df2.plot.barh(x=df2.columns, y=df2.loc[:,:], rot=0)
#
# File C:\ProgramData\miniconda3\envs\pythonEx\lib\site-packages\pandas\plotting\_core.py:1245, in PlotAccessor.barh(self, x, y, **kwargs)
#    1161 @Appender(
#    1162     """
#    1163     See Also
#    (...)
#    1234 @Appender(_bar_or_line_doc)
#    1235 def barh(self, x=None, y=None, **kwargs) -> PlotAccessor:
#    1236     """
#    1237     Make a horizontal bar plot.
#    1238
#    (...)
#    1243     other axis represents a measured value.
#    1244     """
# -> 1245     return self(kind="barh", x=x, y=y, **kwargs)
#
# File C:\ProgramData\miniconda3\envs\pythonEx\lib\site-packages\pandas\plotting\_core.py:966, in PlotAccessor.__call__(self, *args, **kwargs)
#     964         x = data_cols[x]
#     965     elif not isinstance(data[x], ABCSeries):
# --> 966         raise ValueError("x must be a label or position")
#     967     data = data.set_index(x)
#     968 if y is not None:
#     969     # check if we have y as int or list of ints
#
# ValueError: x must be a label or position
